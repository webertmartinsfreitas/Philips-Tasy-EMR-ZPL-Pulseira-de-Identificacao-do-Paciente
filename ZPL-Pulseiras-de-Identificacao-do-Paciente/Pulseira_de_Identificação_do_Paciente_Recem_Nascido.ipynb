# %% [markdown]
# **Descrição:** Código ZPL completo da pulseira de identificação de pacientes gerais.
# *   **Código:** CWMF-85
# *   **Descrição:** Pulseira Identificação do Paciente (Recém Nascido)
#
# ![Pulseira-de-Identificacao-do-Paciente-Recem-Nascido.png](data:image/png;base64,...)

# %% [markdown]
# **# Código ZPL Completo Sem Comentários**

# %%
^XA
^POI
~SD20
^FO[PosHor(320)],250^BY2,2,100^BKN,100,N,N^FD &NR_ATEND_RN^FS
^FO[PosHor(460)],380^AER,28,15^FDPaciente: &NM_PACIENTE^FS
^FO[PosHor(435)],380^ADR,18,10^FDAtendimento Mae: &NR_ATENDIMENTO_MAE^FS
^FO[PosHor(435)],700^ADR,18,10^FDAtendimento RN: &NR_ATEND_RN^FS
^FO[PosHor(435)],1000^ADR,18,10^FDProntuario RN: &NR_PRONTUARIO_RN^FS
^FO[PosHor(405)],380^ADR,18,10^FDAdmissao RN: &DT_ENTRADA^FS
^FO[PosHor(405)],700^ADR,18,10^FDNascimento RN: &DT_NASCIMENTO_RN^FS
^FO[PosHor(375)],380^ADR,18,10^FDTipo Sanguineo RN: &DS_TIPO_SANGUE_RH^FS
^FO[PosHor(375)],700^ADR,18,10^FDSexo RN: &IE_SEXO_RN^FS
^FO[PosHor(375)],1000^ADR,18,10^FDPeso RN: &NR_PESO_RN^FS
^FO[PosHor(345)],380^ADR,18,10^FDNome da Mae: &NM_MAE^FS
^FO[PosHor(315)],380^ADR,18,10^FDMedico: &NM_PEDIATRA^FS
^FO[PosHor(460)],1310^AER,18,10^FDP-RN^FS
^FO[PosHor(350)],1200^BQN,2,5^FDQA,&CD_PESSOA_FISICA^FS
^FO[PosHor(310)],1285^AER,18,10^FDCWMF-85^FS
^XZ
^JUa

# %% [markdown]
# **# Expliacação Linha a Linha do Código**
